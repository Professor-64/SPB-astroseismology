# %%
import tessutils as tu
# %matplotlib widget

# %%
TIC = 375038081

tu.reduction.download_tpf(TIC, sectors=[61, 62, 63])
# Out:
# Saved: tpfs/tic375038081_sec61.fits
# Saved: tpfs/tic375038081_sec63.fits
# Saved: tpfs/tic375038081_sec62.fits
